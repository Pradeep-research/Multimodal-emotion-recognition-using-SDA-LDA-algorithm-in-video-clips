# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
from sklearn import svm
import sklearn.model_selection as cv
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import numpy as np
import random
import pickle

# %%
pickle_in = open("Data_Anger" , "rb")
a0 = pickle.load(pickle_in)
pickle_in.close()

pickle_in = open("Data_Disgust" , "rb")
a1 = pickle.load(pickle_in)
pickle_in.close()

pickle_in = open("Data_Fear" , "rb")
a2 = pickle.load(pickle_in)
pickle_in.close()

pickle_in = open("Avg_Data" , "rb")  
a3 = pickle.load(pickle_in)
pickle_in.close()

pickle_in = open("Data_Sadness" , "rb")
a4 = pickle.load(pickle_in)  
pickle_in.close()

pickle_in = open("Data_Suprise" , "rb")
a5 = pickle.load(pickle_in)
pickle_in.close()

print(len(a0))
print(len(a1))
print(len(a2))
print(len(a3))
print(len(a4))
print(len(a5))
# Out:
# 206
# 219
# 198
# 191
# 200
# 205

# %%
for i in a1:
    a0.append(i)
for i in a2:
    a0.append(i)
for i in a3:
    a0.append(i)
for i in a4:
    a0.append(i)
for i in a5:
    a0.append(i)
print(len(a0))
# Out:
# 1219

# %%
print(a0)
pickle_out = open("Video_Data","wb")
pickle.dump(mfcc_data,pickle_out)
pickle_out.close()
# Out:
# [array([109.93179704, 155.92626463, 110.13627922, 105.01904589,
#        220.09543385, 117.17508268, 110.53506231,  83.60023923,
#         39.20459157,   0.        ]), array([114.28473214, 161.22654868, 116.7647207 , 106.11785901,
#        226.55683614, 128.86038957, 125.80143083,  87.20091743,
#         40.60788101,   0.        ]), array([107.83784122, 167.94344286, 113.15917992, 107.04204781,
#        229.94129686, 116.92732786, 117.65202931,  89.02246907,
#         40.44749683,   0.        ]), array([106.85036266, 178.10390226, 111.04053314, 107.28000746,
#        235.8495283 , 110.16805345, 115.41230437,  96.25487001,
#         40.11234224,   0.        ]), array([102.45974819, 166.68833193, 105.30906894, 105.17128886,
#        225.51496624, 111.94641575, 106.62551289,  91.0659102 ,
#         34.13209633,   0.        ]), array([131.10682667, 162.8250595 , 134.03357788, 100.7174265 ,
#        220.8393081 , 141.42135624, 140.91131963,  75.2861209 ,
# ...

# %%
X = []
y = []
#deleteing the last element as it contains the category number and 
for i in a0:
    a = np.delete(i,-1)
    X.append(a)
for j in range(len(a0)):
    y.append(0)
for i in a1:
    a = np.delete(i,-1)
    X.append(a)
for j in range(len(a1)):
    y.append(1)
for i in a2:
    a = np.delete(i,-1)
    X.append(a)
for j in range(len(a2)):
    y.append(2)
for i in a3:
    a = np.delete(i,-1)
    X.append(a)
for j in range(len(a3)):
    y.append(3)
for i in a4:
    a = np.delete(i,-1)
    X.append(a)
for j in range(len(a4)):
    y.append(4)
for i in a5:
    a = np.delete(i,-1)
    X.append(a)
for j in range(len(a5)):
    y.append(5)
print(len(X))
print(len(y))
# Out:
# 1219
# 1219
# [array([109.93179704, 155.92626463, 110.13627922, 105.01904589,
#        220.09543385, 117.17508268, 110.53506231,  83.60023923,
#         39.20459157]), array([114.28473214, 161.22654868, 116.7647207 , 106.11785901,
#        226.55683614, 128.86038957, 125.80143083,  87.20091743,
#         40.60788101]), array([107.83784122, 167.94344286, 113.15917992, 107.04204781,
#        229.94129686, 116.92732786, 117.65202931,  89.02246907,
#         40.44749683]), array([106.85036266, 178.10390226, 111.04053314, 107.28000746,
#        235.8495283 , 110.16805345, 115.41230437,  96.25487001,
#         40.11234224]), array([102.45974819, 166.68833193, 105.30906894, 105.17128886,
#        225.51496624, 111.94641575, 106.62551289,  91.0659102 ,
#         34.13209633]), array([131.10682667, 162.8250595 , 134.03357788, 100.7174265 ,
#        220.8393081 , 141.42135624, 140.91131963,  75.2861209 ,
#         32.55764119]), array([130.23056477, 168.76018488, 134.03357788,  98.32598843,
# ...

# %%
X_train, X_test, y_train, y_test = cv.train_test_split(X, y, test_size=0.25)

# %%
SVM_clf = svm.SVC(kernel='linear', probability=True)

SVM_clf.fit(X_train, y_train)

y_pred_SVM = SVM_clf.predict(X_test)
print(classification_report(y_test, y_pred_SVM))

   
accuracy_SVM = accuracy_score(y_test, y_pred_SVM)
print('Accuracy of SVM:', accuracy_SVM)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.33      0.33      0.33         3
#            2       0.00      0.00      0.00         1
#            3       0.33      0.33      0.33         3
#            4       0.00      0.00      0.00         3
#            5       0.33      0.33      0.33         3
#
#     accuracy                           0.23        13
#    macro avg       0.17      0.17      0.17        13
# weighted avg       0.23      0.23      0.23        13
#
# Accuracy of SVM: 0.23076923076923078
# C:\Anaconda3\envs\dlib_env\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
