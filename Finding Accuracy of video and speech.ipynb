# %%
import librosa
import numpy as np
import os
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
from sklearn import svm
import sklearn.model_selection as cv
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle

# %%
pickle_in = open("Video_Data","rb")
a1 = pickle.load(pickle_in)
pickle_in.close()

pickle_in = open("Speech_Data","rb")
a2 = pickle.load(pickle_in)
pickle_in.close()

print(len(a1))
print(len(a2))
# Out:
# 1219
# 1225

# %%
X2 = []
X1 , y = zip(*a2)
for i in a1:
    a = np.delete(i,-1)
    X2.append(a)
print(len(X1))
print(len(X2))
# Out:
# 1225
# 1219

# %%
X3 = []
for i in X2:
    a = i.tolist()
    X3.append(a)
print(len(X3))
# Out:
# 1219

# %%
X = []
for i in range(0,1219):
    AA = X3[i] + X1[i]
    X.append(AA)
print(len(X))
# Out:
# 1219

# %%
print(X)
# Out:
# [[109.9317970379817, 155.92626462530293, 110.13627921806692, 105.01904589168576, 220.0954338463204, 117.17508267545622, 110.5350623105628, 83.60023923410746, 39.20459156782532, -182.7078482701228, 104.09117376620952, -55.13761464632474, -6.25288744362501, -55.23497771483201, -7.968547052488877, -30.645672082901, -4.940771346596571, -12.573160467239527, 3.717469800894077, -13.297721744959171, -12.275457233190536, -14.832055506797937, -9.865557989248863, -11.128581182773297, -16.11634921156443, -4.922551258481466, -1.5694676630772078, 4.389156702619332, 6.917745916201518, 0.534056057379796, 5.793623264305866, -3.0906793766296827, 7.8415162911781895, 4.802548289642885, 4.555451043294027, -3.43009845155936, -1.464836119229977, -3.666759291291237, -0.9977716610981868, -2.872522177031407, -1.7776803179429128, 3.0702794934694584, 6.789465304750663, -1.5607164052816538, -2.5321832882670257, -0.35767794797340263, 4.184653063233082, 0.8923173860288584, -7.931630159112124], [114.28473213863697, 161.22654868228122, 116.76472069936193, 106.1178590059185, 226.55683613610074, 128.86038956948718, 125.80143083447024, 87.20091742636656, 40.607881008493905, -154.60660693330584, 98.54658177213848, -74.19463780915962, 16.733896001329963, -57.211783396747876, -19.720672365629447, -27.650331465703136, -3.1283445147410878, -5.880977702590655, -4.409812246572296, -13.69566226061785, -10.133162763602328, -18.490731536217456, -5.108616422791526, -14.603998987179882, -9.135739578953329, -3.2353390070065013, -8.11564918059223, -7.077006290543754, -5.950677822221, -6.674801925724408, 4.347863219818979, 2.633934984229646, 20.237116803538125, 6.102920513389246, 9.573790607165616, -5.601587603958148, 0.3183509766493203, 0.7570916315154085, 3.851301185646147, 3.356676879637646, 0.3093056785610487, 0.015630039263446378, 7.165766738214582, -0.049107562539712435, 0.8951734456251252, -0.07332042337588544, 0.16323206447205454, -3.372700566953083, -11.047984440371675], [107.83784122468327, 167.94344286098223, 113.1591799192624, 107.0420478129973, 229.94129685639334, 116.92732785794773, 117.65202930676547, 89.02246907382428, 40.44749683231337, -176.65916022074592, 102.13586389403983, -74.3342885110796, 7.192505572874522, -50.08026748342613, -7.517860733049432, -23.843310665838498, -6.750188543931725, -11.756219881097065, -4.569646525014307, -12.680034190109096, -9.58298845665971, -18.5949864104851, -3.557811848127965, -13.148585199234413, -12.515378394077734, -2.2211482902777564, -3.822562583021282, 1.9842371286190663, -0.6059526515375707, 0.11466658130748984, 0.34147171445728575, 0.5197191969635561, 11.974969829019813, -3.7032664127878308, 3.100885149744368, -9.476044799556437, 0.7011872975482154, 0.6122538945109574, 6.460110439774916, 2.5623526407271315, -2.938400595304892, 2.305505740120239, 5.920383578723239, -2.1414851902686443, 0.2500048020144099, -6.137670262419071, -2.3765074352628175, -0.1528097150520873, -4.255437932985345], [106.85036265731624, 178.10390225932727, 111.04053313993049, 107.28000745712129, 235.8495283014151, 110.16805344563369, 115.41230437002807, 96.25487000666512, 40.11234224026316, -185.1779959221848, 97.04178931933491, -75.93109950498372, 3.578223845037092, -51.76069487718975, -10.433352276682854, -26.29623088816635, -9.074915729150051, -10.924803382208367, -0.3335845575613134, -17.501114200644132, -11.433152211313487, -10.88622522304038, -3.3977019336043286, -11.934991300106049, -14.407916328987154, 3.186716992564562, -8.13572933518586, 3.8809444822934496, 6.886561441509163, 3.9503022615148238, 12.219493190781408, 1.045364908060106, 17.108808063659346, -3.9168760706396664, -3.307706534486859, -4.696192636209376, -6.171171789660173, -2.1199334879883196, 3.2199414680484963, -4.328436725780744, -2.035384466668137, -1.6854682807661907, 3.7972164825231087, 1.9347013640804451, -3.1716335544816587, -5.06719818548495, 0.7425519876620349, 3.7111017461083518, -3.651664460907463], [102.45974819410792, 166.68833192518306, 105.30906893520614, 105.171 ...

# %%
y = list(y)
y.pop(190)
y.pop(380)
y.pop(570)
y.pop(760)
y.pop(950)
y.pop(1140)
print(len(y))
# Out:
# 1219

# %%
X_train, X_test, y_train, y_test = cv.train_test_split(X, y, test_size=0.25)
SVM_clf = svm.SVC(kernel='linear', probability=True)

SVM_clf.fit(X_train, y_train)

y_pred_SVM = SVM_clf.predict(X_test)
print(classification_report(y_test, y_pred_SVM))

   
accuracy_SVM = accuracy_score(y_test, y_pred_SVM)
print('Accuracy of SVM:', accuracy_SVM)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.66      0.57        53
#            1       0.46      0.51      0.49        49
#            2       0.36      0.23      0.28        60
#            3       0.44      0.52      0.48        46
#            4       0.37      0.47      0.42        40
#            5       0.46      0.30      0.36        57
#
#     accuracy                           0.44       305
#    macro avg       0.43      0.45      0.43       305
# weighted avg       0.43      0.44      0.43       305
#
# Accuracy of SVM: 0.43934426229508194
